# %%
import os
import numpy as np
import pandas as pd
import geopandas as gpd
from tqdm import tqdm
import matplotlib.pyplot as plt
import pygeos
import pyproj
from scipy.stats import linregress

# %%
# set data paths to results
data_path_perc = r'C:\Data\percolation_results'
data_path_met= r'C:\Data\percolation_metrics'
data_path_net = r'C:\Data\percolation_networks'

# file to get full country names
glob_info = pd.read_excel(r'C:\trails\data\global_information.xlsx')
gdp_cap_country = pd.read_csv(r'C:\trails\data\percolation\worldbank_gdp_2019.csv')
income_groups = pd.read_excel(r'C:\trails\data\percolation\CLASS.xls',sheet_name='Groups')


# get all files from data paths
perc_files = os.listdir(data_path_perc) 
met_files = os.listdir(data_path_met) 
net_files = os.listdir(data_path_net)

# %%
income_groups = income_groups.loc[(income_groups.GroupName.str.contains('High income')) | (
     income_groups.GroupName.str.contains('Upper middle income')) | (
     income_groups.GroupName.str.contains('Lower middle income')) | (
     income_groups.GroupName.str.contains('Low income'))].reset_index(drop=True)
#income_groups.loc[income_groups.GroupName.str.contains('Low income')]

# %%
gadm36 = gpd.read_file(r'C:/Data/GADM/gadm36_levels.gpkg',layer=0)

# %%
py_geoms = pygeos.from_shapely(gadm36.geometry.values)

# %%
def get_area_km2(geometries):
    """This method adds a distance column using pygeos (converted from shapely) 
    assuming the new crs from the latitude and longitude of the first node
    distance is in metres

    Args:
        network (class): A network composed of nodes (points in space) and edges (lines)

    Returns:
        network (class): A network composed of nodes (points in space) and edges (lines)
    """    

    #Find crs of current df and arbitrary point(lat,lon) for new crs
    current_crs="epsg:4326"
    #The commented out crs does not work in all cases
    #current_crs = [*network.edges.crs.values()]
    #current_crs = str(current_crs[0])
    lat = pygeos.get_y(pygeos.centroid(geometry))
    lon = pygeos.get_x(pygeos.centroid(geometry))
    # formula below based on :https://gis.stackexchange.com/a/190209/80697 
    approximate_crs = "epsg:" + str(int(32700-np.round((45+lat)/90,0)*100+np.round((183+lon)/6,0)))
    #from pygeos/issues/95
    coords = pygeos.get_coordinates(geometry)
    transformer=pyproj.Transformer.from_crs(current_crs, approximate_crs,always_xy=True)
    new_coords = transformer.transform(coords[:, 0], coords[:, 1])
    result = pygeos.set_coordinates(geometry, np.array(new_coords).T)
    return pygeos.area(result)

# %%
collect_area = []
for geometry in tqdm(py_geoms,total=len(py_geoms)):
    collect_area.append(get_area_km2(geometry)/1e6) 
gadm36['area'] = collect_area
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 256/256 [01:01<00:00,  4.14it/s]

# %%
area_dict = dict(zip(gadm36['GID_0'],gadm36['area']))
continent_dict = dict(zip(glob_info['ISO_3digit'],glob_info['continent']))
gdp_cap_dict = dict(zip(gdp_cap_country['iso'],gdp_cap_country['gdp']))
income_dict = dict(zip(income_groups['CountryCode'],income_groups['GroupName']))

# %%
collect_metrics = {}

for iter1,file in tqdm(enumerate(perc_files),total=len(perc_files)):

    net_name = file[:5]
    
    try:
        net_name = dict(zip(glob_info.ISO_3digit,glob_info.Country))[net_name[:3]]
        df_metrics = pd.read_csv(os.path.join(data_path_met,[x for x in met_files if file[:5] in x][0]))
        
        df = pd.read_csv(os.path.join(data_path_perc,file),index_col=[0])
    except:
        continue
        
    
    if file[:5] == 'ALB_0':
        break
# Out:
#   1%|█                                                                                 | 3/235 [00:00<00:28,  8.13it/s]

# %%
df.groupby('frac_counter').mean()[['pct_isolated', 'pct_unaffected', 'pct_delayed','total_pct_surplus_loss_e1','total_pct_surplus_loss_e2']].plot()
# Out:
# <AxesSubplot:xlabel='frac_counter'>

# %%
df.groupby('frac_counter').mean()
# Out:
#               pct_isolated  pct_unaffected  pct_delayed  \
# frac_counter
# 0.01              1.074141       43.010707    55.915152
# 0.02              2.574949       23.991717    73.433333
# 0.03              4.367879       15.509697    80.122424
# 0.04              5.723232       11.133131    83.143636
# 0.05              8.123232        8.412525    83.464242
# 0.06             11.669495        6.506869    81.823636
# 0.07             14.416566        5.139192    80.444242
# 0.08             18.030909        4.249495    77.719596
# 0.09             21.466465        3.449091    75.084444
# 0.10             25.378586        2.870303    71.751111
# 0.11             29.654949        2.411515    67.933535
# 0.12             35.550101        2.104646    62.345253
# 0.13             40.973737        1.868687    57.157576
# 0.14             47.699192        1.639192    50.661616
# 0.15             52.296364        1.436364    46.267273
# 0.16             59.470303        1.252323    39.277374
# 0.17             63.489293        1.116162    35.394545
# 0.18             68.895152        0.998586    30.106263
# 0.19             73.444040        0.901212    25.654747
# 0.20             76.734545        0.811313    22.454141
# 0.21             80.292323        0.742020    18.965657
# 0.22             83.480404        0.669697    15.849899
# 0.23             86.528283        0.613535    12.858182
# 0.24             89.234949        0.559596    10.205455
# 0.25             91.590909        0.520606     7.888485
# 0.26             92.917980        0.478586     6.603434
# 0.27             94.009495        0.448485     5.542020
# 0.28             95.061818        0.422424     4.515758
# 0.29             96.100606        0.387475     3.511919
# 0.30             96.794343        0.361818     2.843838
# 0.32             97.738384        0.321010     1.940606
# 0.34             98.529091        0.281818     1.189091
# 0.36             98.943636        0.246667     0.809697
# 0.38             99.230505        0.214141     0.555354
# 0.40             99.417576        0.187475     0.394949
# 0.42             99.534343        0.166465     0.299192
# 0.44             99.634545        0.145051     0.220404
# 0.46             99.706869        0.128889     0.164242
# 0.48             99.755152        0.114949     0.129899
# 0.50             99.799192        0.102828     0.097980
# 0.55             99.873333        0.075354     0.051313
# 0.60             99.917172        0.055960     0.026869
# 0.65             99.939798        0.041010     0.019192
# 0.70             99.955556        0.031515     0.012929
# 0.75             99.970101        0.022020     0.007879
# 0.80             99.979798        0.014545     0.005657
# 0.85             99.986465        0.009697     0.003838
# 0.90             99.990505        0.006667     0.002828
# 0.95             99.994545        0.003838     0.001616
# 1.00             99.999394        0.000202     0.000404
#
#               average_time_disruption  total_surp_loss_e1  \
# frac_counter
# 0.01                         0.130931        38602.986373
# 0.02                         0.229221        66254.504762
# 0.03                         0.322868        87047.465847
# 0.04                         0.429036       105110.209337
# 0.05                         0.523971       118327.961917
# 0.06                         0.643701       131515.835699
# 0.07                         0.745998       141972.274271
# 0.08                         0.825682       150742.121884
# 0.09                         0.926442       158819.764751
# 0.10                         1.052395       166335.769020
# 0.11                         1.125879       172360.452344
# 0.12                         1.130257       178861.963047
# 0.13                         1.159539       185579.938448
# 0.14                         1.149095       191208.745925
# 0.15                         1.222805       196492.691160
# 0.16                         1.150648       200800.506624
# 0.17                         1.172717       206015.023018
# 0.18                         1.126863       211203.890420
# 0.19                         1.062236       215562.338692
# 0.20                         1.082366       219172.343941
# 0.21                         1.072220       222734.748559
# 0.22                         1.078900       225171.641217
# 0.23                         1.054983       227817.175203
# 0.24                         0.987895       230607.250507
# 0.25                         0.880948       232882.566433
# 0.26                         0.842979       234403.694877
# 0.27                         0.802577       235864.809725
# 0.28                         0.744350       236799.373874
# 0.29                         0.666973       237927.970166
# 0.30                         0.640043       238338.786173
# 0.32                         0.578383       239186.630589
# 0.34                         0.493722       239843.214178
# 0.36                         0.430535       240022.947433
# 0.38                         0.397250       240164.944246
# 0.40                         0.377401       240177.774568
# 0.42                         0.357309       240198.509594
# 0.44                         0.319616       240200.750426
# 0.46                         0.318288       240211.136093
# 0.48                         0.314940       240211.867399
# 0.50                         0.319977       240212.384667
# 0.55                         0.317758       240214.160268
# 0.60                         0.349885       240214.689696
# 0.65                         0.397443       240214.883180
# 0.70                         0.375875       240215.009117
# 0.75                         0.465927       240215.129911
# 0.80                         0.502387       240215.203270
# 0.85                         0.632525       240215.255941
# 0.90                         0.744467       240215.280000
# 0.95                         0.652752       240215.301000
# 1.00                         0.579729       240215.328000
#
#               total_pct_surplus_loss_e1  total_surp_loss_e2  \
# frac_counter
# 0.01                          16.075846        64791.005804
# 0.02                          27.578153       118364.776901
# 0.03                          36.242295       163458.871858
# 0.04                          43.752690       202422.004764
# 0.05                          49.259179       233071.985974
# 0.06                          54.750219       264185.754610
# 0.07                          59.107457       288318.941709
# 0.08                          62.753926       309250.070057
# 0.09                          66.106447       328580.069482
# 0.10                          69.238864       348223.989055
# 0.11                          71.748826       363991.736983
# 0.12                          74.442176       381896.694206
# 0.13                          77.241674       400846.077436
# 0.14                          79.592112       417241.753281
# 0.15                          81.790707       432284.640505
# 0.16                          83.582299       446035.057495
# 0.17                          85.752282       460866.545987
# 0.18                          87.917892       477090.090012
# 0.19                          89.733946       491304.204512
# 0.20                          91.234861       503150.119312
# 0.21                          92.722473       515803.616339
# 0.22                          93.737264       524107.889907
# 0.23                          94.840039       533150.510222
# 0.24                          96.006213       543142.785986
# 0.25                          96.953077       551334.528495
# 0.26                          97.585448       556479.115599
# 0.27                          98.188977       561535.707950
# 0.28                          98.579230       565215.869100
# 0.80                          99.999947             0.796401         0.796638
# 0.85                          99.999969             0.845989         0.845789
# 0.90                          99.999979             0.894861         0.894797
# 0.95                          99.999988             0.944197         0.944260
# 1.00                          99.999999             0.993739         0.993669

# %%
pd.DataFrame(df.delayed_percentiles.values.tolist()[:10])
# Out:
#                                                    0
# 0  [5.164473895846733e-05, 5.164473895846733e-05,...
# 1  [0.0006476716047500997, 0.007734870874906596, ...
# 2  [2.121783732067506e-05, 0.0006688894420707747,...
# 3  [2.121783732067506e-05, 0.0006688894420707747,...
# 4  [2.121783732067506e-05, 0.0006911452525970585,...
# 5  [2.121783732067506e-05, 0.0007224557146712218,...
# 6  [2.121783732067506e-05, 0.0007224557146712218,...
# 7  [2.121783732067506e-05, 0.0010247650455752488,...
# 8  [2.121783732067506e-05, 0.0006911452525970585,...
# 9  [0.00014905583242152964, 0.001958576567614667,...

# %%
df[['delayed_10thperc','delayed_25thperc','delayed_50thperc','delayed_75thperc','delayed_90thperc','delayed_mean']] = pd.DataFrame(df.delayed_percentiles.tolist(), index= df.index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-9ff90d04bea2> in <module>
# ----> 1 df[['delayed_10thperc','delayed_25thperc','delayed_50thperc','delayed_75thperc','delayed_90thperc','delayed_mean']] = pd.DataFrame(df.delayed_percentiles.tolist(), index= df.index)
#
# ~\.conda\envs\py38\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3035             self._setitem_frame(key, value)
#    3036         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3037             self._setitem_array(key, value)
#    3038         else:
#    3039             # set column
#
# ~\.conda\envs\py38\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    3061             if isinstance(value, DataFrame):
#    3062                 if len(value.columns) != len(key):
# -> 3063                     raise ValueError("Columns must be same length as key")
#    3064                 for k1, k2 in zip(key, value.columns):
#    3065                     self[k1] = value[k2]
#
# ValueError: Columns must be same length as key

# %%
df[['unaff_10thperc','unaff_25thperc','unaff_50thperc','unaff_75thperc','unaff_90thperc','unaff_mean']]

# %%
df.unaffected_percentiles[:30].values.tolist()
# Out:
# ['[0.07673858312922566, 0.12240478611338235, 0.19074746366889284, 0.2907759176025808, 0.3525125574108734, 0.20592148197271362]',
#  '[0.096177412890188, 0.15919495822861307, 0.23449827207782215, 0.30396460592399005, 0.3554540996460287, 0.23266567921109294]',
#  '[0.08421435912903852, 0.13070812330578718, 0.20309645506311447, 0.28297005334347575, 0.340095478308412, 0.20918589225551742]',
#  '[0.08239556452124774, 0.1276560723490865, 0.19398442576024744, 0.2746215597115771, 0.33597330656819446, 0.20365110515350487]',
#  '[0.08203264841249801, 0.12438689541985126, 0.19070893400320665, 0.2733554750026532, 0.3342766917447938, 0.20187383437775736]',
#  '[0.08195644678743941, 0.12261904238919552, 0.1872499004343844, 0.27021436859959547, 0.3330989239083282, 0.19998787110306623]',
#  '[0.08132870121192481, 0.1222723836401094, 0.18578142770571493, 0.2689977644848871, 0.3320267827637198, 0.19918503983286856]',
#  '[0.08061784740822114, 0.12041561573917736, 0.18540277824483264, 0.27210467559982754, 0.33762089889286045, 0.2002974875638393]',
